# %%
import pandas as pd

from getBCE.menu import *

# %%
page = getBCE(
    year = '2021',
    month = 'julio',
    indicator = '022',
)

# %%
data = pd.read_excel(page.getHref(), skiprows=8)
df = pd.DataFrame(data)
df.dropna(axis = 0, how = 'all', inplace = True)
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 1  Productivo Corporativo  Productivo Empresarial  \
# 1        2015  Septiembre              142.806303               30.664544
# 2         NaN     Octubre               22.384548               11.759002
# 3         NaN   Noviembre               21.024664                3.029800
# 4         NaN   Diciembre                7.138846                5.365348
# 6        2016       Enero               12.751910                5.805554
# 7         NaN     Febrero               13.996391                3.417253
# 8         NaN       Marzo               31.946836                3.784566
# 9         NaN       Abril               29.400000                1.650000
# 10        NaN        Mayo               32.663137                8.242581
# 11        NaN       Junio               29.930000                5.510000
#
#     Productivo PYMES  Productivo Agrícola y Ganadero (***)  \
# 1          30.178938                                   NaN
# ...
